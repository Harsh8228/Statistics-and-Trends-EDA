# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading the data via pandas read_csv function and understanding the structure and variables.
df = pd.read_csv('/content/ev_charging_patterns.csv', index_col = 'User ID')
df.head(4)
# Out:
#         Vehicle Model  Battery Capacity (kWh) Charging Station ID  \
# User ID
# User_1         BMW i3              108.463007         Station_391
# User_2   Hyundai Kona              100.000000         Station_428
# User_3     Chevy Bolt               75.000000         Station_181
# User_4   Hyundai Kona               50.000000         Station_327
#
#         Charging Station Location Charging Start Time Charging End Time  \
# User ID
# User_1                    Houston    01-01-2024 00:00  01-01-2024 00:39
# User_2              San Francisco    01-01-2024 01:00  01-01-2024 03:01
# User_3              San Francisco    01-01-2024 02:00  01-01-2024 04:48
# User_4                    Houston    01-01-2024 03:00  01-01-2024 06:42
#
#          Energy Consumed (kWh)  Charging Duration (hours)  Charging Rate (kW)  \
# User ID
# User_1               60.712346                   0.591363           36.389181
# User_2               12.339275                   3.133652           30.677735
# User_3               19.128876                   2.452653           27.513593
# User_4               79.457824                   1.266431           32.882870
#
#          Charging Cost (USD) Time of Day Day of Week  \
# User ID
# User_1             13.087717     Evening     Tuesday
# User_2             21.128448     Morning      Monday
# User_3             35.667270     Morning    Thursday
# User_4             13.036239     Evening    Saturday
#
#          State of Charge (Start %)  State of Charge (End %)  \
# User ID
# User_1                   29.371576                86.119962
# User_2                   10.115778                84.664344
# User_3                    6.854604                69.917615
# User_4                   83.120003                99.624328
#
#          Distance Driven (since last charge) (km)  Temperature (°C)  \
# User ID
# User_1                                 293.602111         27.947953
# User_2                                 112.112804         14.311026
# User_3                                  71.799253         21.002002
# User_4                                 199.577785         38.316313
#
#          Vehicle Age (years)     Charger Type               User Type
# User ID
# User_1                   2.0  DC Fast Charger                Commuter
# User_2                   3.0          Level 1           Casual Driver
# User_3                   2.0          Level 2                Commuter
# User_4                   1.0          Level 1  Long-Distance Traveler

# %%
# Understanding the distribution of data and looking for outliers or any anomalies like null values.
df.describe()
# Out:
#        Battery Capacity (kWh)  Energy Consumed (kWh)  \
# count             1320.000000            1254.000000
# mean                74.534692              42.642894
# std                 20.626914              22.411705
# min                  1.532807               0.045772
# 25%                 62.000000              23.881193
# 50%                 75.000000              42.691405
# 75%                 85.000000              61.206218
# max                193.003074             152.238758
#
#        Charging Duration (hours)  Charging Rate (kW)  Charging Cost (USD)  \
# count                1320.000000         1254.000000          1320.000000
# mean                    2.269377           25.963003            22.551352
# std                     1.061037           14.011326            10.751494
# min                     0.095314            1.472549             0.234317
# 25%                     1.397623           13.856583            13.368141
# 50%                     2.258136           25.603799            22.076360
# 75%                     3.112806           37.502998            31.646044
# max                     7.635145           97.342255            69.407743
#
#        State of Charge (Start %)  State of Charge (End %)  \
# count                1320.000000              1320.000000
# mean                   49.130012                75.141590
# std                    24.074134                17.080580
# min                     2.325959                 7.604224
# 25%                    27.786903                62.053266
# 50%                    48.241771                75.682496
# 75%                    69.277921                88.201370
# max                   152.489761               177.708666
#
#        Distance Driven (since last charge) (km)  Temperature (°C)  \
# count                               1254.000000       1320.000000
# mean                                 153.596788         15.263591
# std                                   86.004987         14.831216
# min                                    0.862361        -10.724770
# 25%                                   79.445335          2.800664
# 50%                                  152.259867         14.630846
# 75%                                  226.073284         27.981810
# max                                  398.364775         73.169588
#
#        Vehicle Age (years)
# count          1320.000000
# mean              3.612843
# std               2.309824
# min               0.000000
# 25%               2.000000
# 50%               4.000000
# 75%               6.000000
# max              11.688592

# %% [markdown]
# For almost every variable:
# 1. Mean and 50% values are close
# 2. Most values are within the 3 times of standard deviation range.
# 3. Some inconsistency in 'count' of values is observed due to null values.
#
# The distribution for all numeric variables seems to resemble the normal distribution.

# %%
#Checking for null values
df.isnull().sum()
# Out:
# Vehicle Model                                0
# Battery Capacity (kWh)                       0
# Charging Station ID                          0
# Charging Station Location                    0
# Charging Start Time                          0
# Charging End Time                            0
# Energy Consumed (kWh)                       66
# Charging Duration (hours)                    0
# Charging Rate (kW)                          66
# Charging Cost (USD)                          0
# Time of Day                                  0
# Day of Week                                  0
# State of Charge (Start %)                    0
# State of Charge (End %)                      0
# Distance Driven (since last charge) (km)    66
# Temperature (°C)                             0
# Vehicle Age (years)                          0
# Charger Type                                 0
# User Type                                    0
# dtype: int64

# %%
''' Checking in how many distinct rows do null values exist.'''
df.isna().any(axis=1).sum()
# Out:
# 189

# %% [markdown]
# The null values across the parameters occur in different rows. If we choose to drop the null values, we would loose total 189 rows of data which accounts for 14% of total data. Observing that null values only occur in numeric columns we will replace it with mean of that column so, we don't have to drop a significant portion of the data.

# %%
''' Replacing the null values with mean of the column. '''

for i, cols in enumerate(df.columns):
  if cols in ['Energy Consumed (kWh)', 'Charging Rate (kW)', 'Distance Driven (since last charge) (km)']:
    df[cols] = df[cols].fillna(df[cols].mean())
  else:
    continue

# %%
''' Now the count of all variables is same'''
df.describe()
# Out:
#        Battery Capacity (kWh)  Energy Consumed (kWh)  \
# count             1320.000000            1320.000000
# mean                74.534692              42.642894
# std                 20.626914              21.843792
# min                  1.532807               0.045772
# 25%                 62.000000              24.868084
# 50%                 75.000000              42.642894
# 75%                 85.000000              60.545496
# max                193.003074             152.238758
#
#        Charging Duration (hours)  Charging Rate (kW)  Charging Cost (USD)  \
# count                1320.000000         1320.000000          1320.000000
# mean                    2.269377           25.963003            22.551352
# std                     1.061037           13.656279            10.751494
# min                     0.095314            1.472549             0.234317
# 25%                     1.397623           14.431294            13.368141
# 50%                     2.258136           25.963003            22.076360
# 75%                     3.112806           36.955838            31.646044
# max                     7.635145           97.342255            69.407743
#
#        State of Charge (Start %)  State of Charge (End %)  \
# count                1320.000000              1320.000000
# mean                   49.130012                75.141590
# std                    24.074134                17.080580
# min                     2.325959                 7.604224
# 25%                    27.786903                62.053266
# 50%                    48.241771                75.682496
# 75%                    69.277921                88.201370
# max                   152.489761               177.708666
#
#        Distance Driven (since last charge) (km)  Temperature (°C)  \
# count                               1320.000000       1320.000000
# mean                                 153.596788         15.263591
# std                                   83.825619         14.831216
# min                                    0.862361        -10.724770
# 25%                                   81.931571          2.800664
# 50%                                  153.596788         14.630846
# 75%                                  221.962330         27.981810
# max                                  398.364775         73.169588
#
#        Vehicle Age (years)
# count          1320.000000
# mean              3.612843
# std               2.309824
# min               0.000000
# 25%               2.000000
# 50%               4.000000
# 75%               6.000000
# max              11.688592

# %% [markdown]
# Dropping the columns 'Charging Station ID', 'Charging Start Time' and 'Charging End Time' because they have too many unique values so, we won't be able to do one hot encoding on it. Moreover, the first variable doesn't contribute much to the data in terms of a trend or distribution. As for later two, they are not needed as we have alternative columns to show charging time trends.

# %%
df = df.drop(['Charging Station ID', 'Charging Start Time', 'Charging End Time'], axis=1)

# %% [markdown]
# To find the correlation between the variables, we first need to convert the categorical variables into numeric ones by one hot encoding method.

# %%
''' To be able to see entire correlation matrix.'''

pd.set_option("display.max_columns", None)

# %%
''' drop_first method in this function ensures that for one column with N distinct categories, we encode it to N-1 values only.'''

df_encod = pd.get_dummies(df, drop_first = True)

''' printing correlation matrix and saving it into another dataframe as well to make finding strong correlation easier.'''

corr_mat = df_encod.corr()
df_encod.corr()
# Out:
#                                           Battery Capacity (kWh)  \
# Battery Capacity (kWh)                                  1.000000
# Energy Consumed (kWh)                                   0.000316
# Charging Duration (hours)                              -0.024824
# Charging Rate (kW)                                      0.015552
# Charging Cost (USD)                                    -0.000492
# State of Charge (Start %)                              -0.072148
# State of Charge (End %)                                -0.011512
# Distance Driven (since last charge) (km)               -0.040069
# Temperature (°C)                                       -0.036411
# Vehicle Age (years)                                     0.037673
# Vehicle Model_Chevy Bolt                               -0.014965
# Vehicle Model_Hyundai Kona                              0.020972
# Vehicle Model_Nissan Leaf                              -0.040806
# Vehicle Model_Tesla Model 3                            -0.018464
# Charging Station Location_Houston                      -0.019599
# Charging Station Location_Los Angeles                   0.010613
# Charging Station Location_New York                      0.037707
# Charging Station Location_San Francisco                 0.033006
# Time of Day_Evening                                     0.032548
# Time of Day_Morning                                     0.016271
# Time of Day_Night                                      -0.027038
# Day of Week_Monday                                      0.007902
# Day of Week_Saturday                                   -0.004130
# Day of Week_Sunday                                      0.019626
# Day of Week_Thursday                                    0.008664
# Day of Week_Tuesday                                    -0.014417
# Day of Week_Wednesday                                   0.020267
# Charger Type_Level 1                                    0.012108
# Charger Type_Level 2                                   -0.001796
# User Type_Commuter                                      0.009218
# User Type_Long-Distance Traveler                       -0.014165
#
#                                           Energy Consumed (kWh)  \
# Battery Capacity (kWh)                                 0.000316
# Energy Consumed (kWh)                                  1.000000
# Charging Duration (hours)                              0.027770
# Charging Rate (kW)                                    -0.040284
# Charging Cost (USD)                                   -0.007608
# State of Charge (Start %)                             -0.013153
# State of Charge (End %)                                0.000579
# Distance Driven (since last charge) (km)              -0.026369
# Temperature (°C)                                      -0.017999
# Vehicle Age (years)                                    0.016727
# Vehicle Model_Chevy Bolt                              -0.040577
# Vehicle Model_Hyundai Kona                             0.004125
# Vehicle Model_Nissan Leaf                             -0.002970
# Vehicle Model_Tesla Model 3                            0.042178
# Charging Station Location_Houston                      0.032251
# Charging Station Location_Los Angeles                 -0.028830
# Charging Station Location_New York                    -0.008843
# Charging Station Location_San Francisco               -0.010470
# Time of Day_Evening                                    0.015618
# Time of Day_Morning                                   -0.017804
# Time of Day_Night                                     -0.014665
# Day of Week_Monday                                    -0.018135
# Day of Week_Saturday                                  -0.008100
# Day of Week_Sunday                                     0.006026
# Day of Week_Thursday                                  -0.004046
# Day of Week_Tuesday                                   -0.017914
# Day of Week_Wednesday                                  0.033907
# Charger Type_Level 1                                  -0.032940
# Charger Type_Level 2                                   0.074079
# User Type_Commuter                                    -0.042261
# User Type_Long-Distance Traveler                      -0.009695
#
#                                           Charging Duration (hours)  \
# Battery Capacity (kWh)                                    -0.024824
# Energy Consumed (kWh)                                      0.027770
# Charging Duration (hours)                                  1.000000
# Charging Rate (kW)                                        -0.013078
# Charging Cost (USD)                                        0.015902
# State of Charge (Start %)                                 -0.026016
# State of Charge (End %)                                    0.006958
# Distance Driven (since last charge) (km)                   0.023094
# Temperature (°C)                                          -0.049575
# Vehicle Age (years)                                        0.001111
# Vehicle Model_Chevy Bolt                                   0.084768
# Vehicle Model_Hyundai Kona                                 0.001281
# Vehicle Model_Nissan Leaf                                 -0.054943
# Vehicle Model_Tesla Model 3                                0.006220
# Charging Station Location_Houston                          0.003678
# Charging Station Location_Los Angeles                     -0.013158
# Charging Station Location_New York                        -0.034760
# Charging Station Location_San Francisco                    0.061577
# Time of Day_Evening                                       -0.009616
# Time of Day_Morning                                       -0.021336
# Time of Day_Night                                          0.050562
# Day of Week_Monday                                        -0.028431
# Day of Week_Saturday                                      -0.024230
# Day of Week_Sunday                                        -0.060085
# Day of Week_Thursday                                       0.044018
# Day of Week_Tuesday                                        0.039032
# Day of Week_Wednesday                                      0.002616
# Charger Type_Level 1                                      -0.018244
# Charger Type_Level 2                                       0.009248
# User Type_Commuter                                         0.025339
# User Type_Long-Distance Traveler                          -0.035206
#
#                                           Charging Rate (kW)  \
# Battery Capacity (kWh)                              0.015552
# Energy Consumed (kWh)                              -0.040284
# Charging Duration (hours)                          -0.013078
# Charging Rate (kW)                                  1.000000
# Charging Cost (USD)                                -0.000831
# State of Charge (Start %)                          -0.018711
# State of Charge (End %)                            -0.018247
# Distance Driven (since last charge) (km)            0.030551
# Temperature (°C)                                    0.012465
# Vehicle Age (years)                                -0.049195
# Vehicle Model_Chevy Bolt                           -0.035004
# Vehicle Model_Hyundai Kona                          0.016006
# Vehicle Model_Nissan Leaf                           0.023045
# Vehicle Model_Tesla Model 3                        -0.023212
# Charging Station Location_Houston                   0.026343
# Charging Station Location_Los Angeles              -0.020854
# Charging Station Location_New York                  0.007797
# Charging Station Location_San Francisco            -0.002012
# Time of Day_Evening                                -0.011762
# Time of Day_Morning                                 0.042012
# Time of Day_Night                                  -0.014142
# Day of Week_Monday                                 -0.030456
# Day of Week_Saturday                               -0.009814
# Day of Week_Sunday                                  0.034630
# Day of Week_Thursday                                0.008088
# Day of Week_Tuesday                                 0.002069
# Day of Week_Wednesday                              -0.037480
# Charger Type_Level 1                                0.001886
# Charger Type_Level 2                                0.017854
# User Type_Commuter                                  0.050738
# User Type_Long-Distance Traveler                   -0.037230
#
#                                           Charging Cost (USD)  \
# Battery Capacity (kWh)                              -0.000492
# Energy Consumed (kWh)                               -0.007608
# Charging Duration (hours)                            0.015902
# Charging Rate (kW)                                  -0.000831
# Charging Cost (USD)                                  1.000000
# State of Charge (Start %)                           -0.008653
# State of Charge (End %)                             -0.063174
# Distance Driven (since last charge) (km)            -0.008325
# Temperature (°C)                                     0.059864
# Vehicle Age (years)                                 -0.006487
# Vehicle Model_Chevy Bolt                            -0.013101
# Vehicle Model_Hyundai Kona                           0.041355
# Vehicle Model_Nissan Leaf                            0.050843
# Vehicle Model_Tesla Model 3                          0.001368
# Charging Station Location_Houston                   -0.021162
# Charging Station Location_Los Angeles               -0.000497
# Charging Station Location_New York                  -0.002198
# Charging Station Location_San Francisco             -0.025889
# Time of Day_Evening                                 -0.009703
# Time of Day_Morning                                 -0.007453
# Time of Day_Night                                   -0.012393
# Day of Week_Monday                                  -0.007085
# Day of Week_Saturday                                -0.028772
# Day of Week_Sunday                                  -0.022605
# Day of Week_Thursday                                 0.059044
# Day of Week_Tuesday                                 -0.043297
# Day of Week_Wednesday                                0.027409
# Charger Type_Level 1                                -0.060721
# Charger Type_Level 2                                -0.006427
# User Type_Commuter                                   0.014027
# User Type_Long-Distance Traveler                    -0.022044
#
#                                           State of Charge (Start %)  \
# Battery Capacity (kWh)                                    -0.072148
# Energy Consumed (kWh)                                     -0.013153
# Charging Duration (hours)                                 -0.026016
# Charging Rate (kW)                                        -0.018711
# Charging Cost (USD)                                       -0.008653
# State of Charge (Start %)                                  1.000000
# State of Charge (End %)                                   -0.021410
# Distance Driven (since last charge) (km)                  -0.023023
# Temperature (°C)                                           0.037751
# Vehicle Age (years)                                        0.016635
# Vehicle Model_Chevy Bolt                                   0.006033
# Vehicle Model_Hyundai Kona                                 0.028989
# Vehicle Model_Nissan Leaf                                 -0.020232
# Vehicle Model_Tesla Model 3                               -0.028386
# Charging Station Location_Houston                          0.013747
# Charging Station Location_Los Angeles                      0.047433
# Charging Station Location_New York                        -0.001565
# Charging Station Location_San Francisco                   -0.038068
# Time of Day_Evening                                       -0.039932
# Time of Day_Morning                                        0.025056
# Time of Day_Night                                          0.003159
# Day of Week_Monday                                         0.003395
# Day of Week_Saturday                                      -0.021473
# Day of Week_Sunday                                         0.002438
# Day of Week_Thursday                                       0.022391
# Day of Week_Tuesday                                        0.022084
# Day of Week_Wednesday                                      0.007871
# Charger Type_Level 1                                       0.031706
# Charger Type_Level 2                                      -0.017769
# User Type_Commuter                                         0.020893
# User Type_Long-Distance Traveler                           0.024344
#
#                                           State of Charge (End %)  \
# Battery Capacity (kWh)                                  -0.011512
# Energy Consumed (kWh)                                    0.000579
# Charging Duration (hours)                                0.006958
# Charging Rate (kW)                                      -0.018247
# Charging Cost (USD)                                     -0.063174
# State of Charge (Start %)                               -0.021410
# State of Charge (End %)                                  1.000000
# Distance Driven (since last charge) (km)                 0.024944
# Temperature (°C)                                         0.022027
# Vehicle Age (years)                                      0.015671
# Vehicle Model_Chevy Bolt                                -0.033700
# Vehicle Model_Hyundai Kona                               0.007699
# Vehicle Model_Nissan Leaf                                0.027239
# Vehicle Model_Tesla Model 3                             -0.005957
# Charging Station Location_Houston                       -0.003366
# Charging Station Location_Los Angeles                   -0.048289
# Charging Station Location_New York                       0.044312
# Charging Station Location_San Francisco                  0.020861
# Time of Day_Evening                                     -0.010488
# Time of Day_Morning                                     -0.013326
# Time of Day_Night                                        0.029840
# Day of Week_Monday                                      -0.032817
# Day of Week_Saturday                                     0.084987
# Day of Week_Sunday                                       0.010366
# Day of Week_Thursday                                    -0.048482
# Day of Week_Tuesday                                      0.035103
# Day of Week_Wednesday                                   -0.034995
# Charger Type_Level 1                                     0.006631
# Charger Type_Level 2                                    -0.022819
# User Type_Commuter                                       0.034269
# User Type_Long-Distance Traveler                        -0.060313
#
#                                           Distance Driven (since last charge) (km)  \
# Battery Capacity (kWh)                                                   -0.040069
# Energy Consumed (kWh)                                                    -0.026369
# Charging Duration (hours)                                                 0.023094
# Charging Rate (kW)                                                        0.030551
# Charging Cost (USD)                                                      -0.008325
# State of Charge (Start %)                                                -0.023023
# State of Charge (End %)                                                   0.024944
# Distance Driven (since last charge) (km)                                  1.000000
# Temperature (°C)                                                         -0.023107
# Vehicle Age (years)                                                      -0.030835
# Vehicle Model_Chevy Bolt                                                  0.016740
# Vehicle Model_Hyundai Kona                                                0.043724
# Vehicle Model_Nissan Leaf                                                -0.043878
# Vehicle Model_Tesla Model 3                                               0.018346
# Charging Station Location_Houston                                        -0.038804
# Charging Station Location_Los Angeles                                    -0.026058
# Charging Station Location_New York                                        0.050170
# Charging Station Location_San Francisco                                   0.035894
# Time of Day_Evening                                                      -0.003995
# Time of Day_Morning                                                       0.001630
# Time of Day_Night                                                        -0.035701
# Day of Week_Monday                                                        0.013076
# Day of Week_Saturday                                                      0.009756
# Day of Week_Sunday                                                        0.028933
# Day of Week_Thursday                                                     -0.015175
# Day of Week_Tuesday                                                       0.005879
# Day of Week_Wednesday                                                    -0.035778
# Charger Type_Level 1                                                      0.007185
# Charger Type_Level 2                                                     -0.043631
# User Type_Commuter                                                        0.047292
# User Type_Long-Distance Traveler                                          0.008700
#
#                                           Temperature (°C)  \
# Battery Capacity (kWh)                           -0.036411
# Energy Consumed (kWh)                            -0.017999
# Charging Duration (hours)                        -0.049575
# Charging Rate (kW)                                0.012465
# Charging Cost (USD)                               0.059864
# State of Charge (Start %)                         0.037751
# State of Charge (End %)                           0.022027
# Distance Driven (since last charge) (km)         -0.023107
# Temperature (°C)                                  1.000000
# Vehicle Age (years)                               0.026410
# Vehicle Model_Chevy Bolt                         -0.010664
# Vehicle Model_Hyundai Kona                        0.032848
# Vehicle Model_Nissan Leaf                        -0.001312
# Vehicle Model_Tesla Model 3                       0.000466
# Charging Station Location_Houston                 0.009518
# Charging Station Location_Los Angeles            -0.023667
# Charging Station Location_New York                0.008188
# Charging Station Location_San Francisco           0.042261
# Time of Day_Evening                               0.014668
# Time of Day_Morning                              -0.000069
# Time of Day_Night                                -0.039774
# Day of Week_Monday                               -0.019657
# Day of Week_Saturday                             -0.008535
# Day of Week_Sunday                                0.031906
# Day of Week_Thursday                              0.028218
# Day of Week_Tuesday                              -0.015744
# Day of Week_Wednesday                            -0.040913
# Charger Type_Level 1                              0.005470
# Charger Type_Level 2                              0.006684
# User Type_Commuter                                0.023104
# User Type_Long-Distance Traveler                 -0.046820
#
#                                           Vehicle Age (years)  \
# Battery Capacity (kWh)                               0.037673
# Energy Consumed (kWh)                                0.016727
# Charging Duration (hours)                            0.001111
# Charging Rate (kW)                                  -0.049195
# Charging Cost (USD)                                 -0.006487
# State of Charge (Start %)                            0.016635
# State of Charge (End %)                              0.015671
# Distance Driven (since last charge) (km)            -0.030835
# Temperature (°C)                                     0.026410
# Vehicle Age (years)                                  1.000000
# Vehicle Model_Chevy Bolt                             0.002539
# Vehicle Model_Hyundai Kona                          -0.046216
# Vehicle Model_Nissan Leaf                           -0.003972
# Vehicle Model_Tesla Model 3                          0.010788
# Charging Station Location_Houston                   -0.003473
# Charging Station Location_Los Angeles               -0.007675
# Charging Station Location_New York                   0.032137
# Charging Station Location_San Francisco             -0.021740
# Time of Day_Evening                                 -0.002877
# Time of Day_Morning                                  0.000070
# Time of Day_Night                                    0.016739
# Day of Week_Monday                                  -0.033174
# Day of Week_Saturday                                -0.022087
# Day of Week_Sunday                                   0.016668
# Day of Week_Thursday                                 0.021798
# Day of Week_Tuesday                                  0.035053
# Day of Week_Wednesday                                0.016224
# Charger Type_Level 1                                -0.000441
# Charger Type_Level 2                                -0.016743
# User Type_Commuter                                   0.007581
# User Type_Long-Distance Traveler                    -0.000493
#
#                                           Vehicle Model_Chevy Bolt  \
# Battery Capacity (kWh)                                   -0.014965
# Energy Consumed (kWh)                                    -0.040577
# Charging Duration (hours)                                 0.084768
# Charging Rate (kW)                                       -0.035004
# Charging Cost (USD)                                      -0.013101
# State of Charge (Start %)                                 0.006033
# State of Charge (End %)                                  -0.033700
# Distance Driven (since last charge) (km)                  0.016740
# Temperature (°C)                                         -0.010664
# Vehicle Age (years)                                       0.002539
# Vehicle Model_Chevy Bolt                                  1.000000
# Vehicle Model_Hyundai Kona                               -0.246416
# Vehicle Model_Nissan Leaf                                -0.242931
# Vehicle Model_Tesla Model 3                              -0.254514
# Charging Station Location_Houston                        -0.032724
# Charging Station Location_Los Angeles                     0.033955
# Charging Station Location_New York                       -0.031326
# Charging Station Location_San Francisco                   0.037363
# Time of Day_Evening                                       0.007705
# Time of Day_Morning                                      -0.013916
# Time of Day_Night                                        -0.020336
# Day of Week_Monday                                       -0.037967
# Day of Week_Saturday                                     -0.051619
# Day of Week_Sunday                                       -0.011124
# Day of Week_Thursday                                      0.018702
# Day of Week_Tuesday                                       0.049229
# Day of Week_Wednesday                                     0.041910
# Charger Type_Level 1                                     -0.000073
# Charger Type_Level 2                                      0.013942
# User Type_Commuter                                        0.050617
# User Type_Long-Distance Traveler                          0.001012
#
#                                           Vehicle Model_Hyundai Kona  \
# Battery Capacity (kWh)                                      0.020972
# Energy Consumed (kWh)                                       0.004125
# Charging Duration (hours)                                   0.001281
# Charging Rate (kW)                                          0.016006
# Charging Cost (USD)                                         0.041355
# State of Charge (Start %)                                   0.028989
# State of Charge (End %)                                     0.007699
# Distance Driven (since last charge) (km)                    0.043724
# Temperature (°C)                                            0.032848
# Vehicle Age (years)                                        -0.046216
# Vehicle Model_Chevy Bolt                                   -0.246416
# Vehicle Model_Hyundai Kona                                  1.000000
# Vehicle Model_Nissan Leaf                                  -0.248802
# Vehicle Model_Tesla Model 3                                -0.260665
# Charging Station Location_Houston                           0.005696
# Charging Station Location_Los Angeles                       0.009724
# Charging Station Location_New York                          0.012503
# Charging Station Location_San Francisco                    -0.024552
# Time of Day_Evening                                        -0.020948
# Time of Day_Morning                                        -0.020417
# Time of Day_Night                                           0.013902
# Day of Week_Monday                                          0.003915
# Day of Week_Saturday                                       -0.038120
# Day of Week_Sunday                                          0.018847
# Day of Week_Thursday                                       -0.006079
# Day of Week_Tuesday                                         0.003671
# Day of Week_Wednesday                                       0.022799
# Charger Type_Level 1                                        0.025794
# Charger Type_Level 2                                       -0.051764
# User Type_Commuter                                         -0.019356
# User Type_Long-Distance Traveler                            0.007777
#
#                                           Vehicle Model_Nissan Leaf  \
# Battery Capacity (kWh)                                    -0.040806
# Energy Consumed (kWh)                                     -0.002970
# Charging Duration (hours)                                 -0.054943
# Charging Rate (kW)                                         0.023045
# Charging Cost (USD)                                        0.050843
# State of Charge (Start %)                                 -0.020232
# State of Charge (End %)                                    0.027239
# Distance Driven (since last charge) (km)                  -0.043878
# Temperature (°C)                                          -0.001312
# Vehicle Age (years)                                       -0.003972
# Vehicle Model_Chevy Bolt                                  -0.242931
# Vehicle Model_Hyundai Kona                                -0.248802
# Vehicle Model_Nissan Leaf                                  1.000000
# Vehicle Model_Tesla Model 3                               -0.256978
# Charging Station Location_Houston                          0.040087
# Charging Station Location_Los Angeles                     -0.015966
# Charging Station Location_New York                         0.018203
# Charging Station Location_San Francisco                   -0.014286
# Time of Day_Evening                                       -0.001294
# Time of Day_Morning                                        0.012324
# Time of Day_Night                                          0.024864
# Day of Week_Monday                                        -0.029847
# Day of Week_Saturday                                       0.055859
# Day of Week_Sunday                                         0.002051
# Day of Week_Thursday                                      -0.013845
# Day of Week_Tuesday                                       -0.002093
# Day of Week_Wednesday                                     -0.004293
# Charger Type_Level 1                                      -0.025634
# Charger Type_Level 2                                       0.000431
# User Type_Commuter                                        -0.014906
# User Type_Long-Distance Traveler                           0.015884
#
#                                           Vehicle Model_Tesla Model 3  \
# Battery Capacity (kWh)                                      -0.018464
# Energy Consumed (kWh)                                        0.042178
# Charging Duration (hours)                                    0.006220
# Charging Rate (kW)                                          -0.023212
# Charging Cost (USD)                                          0.001368
# State of Charge (Start %)                                   -0.028386
# State of Charge (End %)                                     -0.005957
# Distance Driven (since last charge) (km)                     0.018346
# Temperature (°C)                                             0.000466
# Vehicle Age (years)                                          0.010788
# Vehicle Model_Chevy Bolt                                    -0.254514
# Vehicle Model_Hyundai Kona                                  -0.260665
# Vehicle Model_Nissan Leaf                                   -0.256978
# Vehicle Model_Tesla Model 3                                  1.000000
# Charging Station Location_Houston                           -0.039843
# Charging Station Location_Los Angeles                       -0.031064
# Charging Station Location_New York                           0.046512
# Charging Station Location_San Francisco                     -0.009266
# Time of Day_Evening                                          0.029957
# Time of Day_Morning                                         -0.005414
# Time of Day_Night                                           -0.022602
# Day of Week_Monday                                           0.030735
# Day of Week_Saturday                                        -0.017830
# Day of Week_Sunday                                           0.044695
# Day of Week_Thursday                                         0.001924
# Day of Week_Tuesday                                         -0.059045
# Day of Week_Wednesday                                       -0.030101
# Charger Type_Level 1                                         0.029714
# Charger Type_Level 2                                        -0.021435
# User Type_Commuter                                           0.000117
# User Type_Long-Distance Traveler                            -0.022434
#
#                                           Charging Station Location_Houston  \
# Battery Capacity (kWh)                                            -0.019599
# Energy Consumed (kWh)                                              0.032251
# Charging Duration (hours)                                          0.003678
# Charging Rate (kW)                                                 0.026343
# Charging Cost (USD)                                               -0.021162
# State of Charge (Start %)                                          0.013747
# State of Charge (End %)                                           -0.003366
# Distance Driven (since last charge) (km)                          -0.038804
# Temperature (°C)                                                   0.009518
# Vehicle Age (years)                                               -0.003473
# Vehicle Model_Chevy Bolt                                          -0.032724
# Vehicle Model_Hyundai Kona                                         0.005696
# Vehicle Model_Nissan Leaf                                          0.040087
# Vehicle Model_Tesla Model 3                                       -0.039843
# Charging Station Location_Houston                                  1.000000
# Charging Station Location_Los Angeles                             -0.268132
# Charging Station Location_New York                                -0.243502
# Charging Station Location_San Francisco                           -0.248816
# Time of Day_Evening                                               -0.016397
# Time of Day_Morning                                                0.005708
# Time of Day_Night                                                  0.067385
# Day of Week_Monday                                                 0.034362
# Day of Week_Saturday                                               0.027849
# Day of Week_Sunday                                                 0.005882
# Day of Week_Thursday                                              -0.038852
# Day of Week_Tuesday                                               -0.003692
# Day of Week_Wednesday                                             -0.032523
# Charger Type_Level 1                                              -0.008393
# Charger Type_Level 2                                              -0.042719
# User Type_Commuter                                                -0.037494
# User Type_Long-Distance Traveler                                   0.037383
#
#                                           Charging Station Location_Los Angeles  \
# Battery Capacity (kWh)                                                 0.010613
# Energy Consumed (kWh)                                                 -0.028830
# Charging Duration (hours)                                             -0.013158
# Charging Rate (kW)                                                    -0.020854
# Charging Cost (USD)                                                   -0.000497
# State of Charge (Start %)                                              0.047433
# State of Charge (End %)                                               -0.048289
# Distance Driven (since last charge) (km)                              -0.026058
# Temperature (°C)                                                      -0.023667
# Vehicle Age (years)                                                   -0.007675
# Vehicle Model_Chevy Bolt                                               0.033955
# Vehicle Model_Hyundai Kona                                             0.009724
# Vehicle Model_Nissan Leaf                                             -0.015966
# Vehicle Model_Tesla Model 3                                           -0.031064
# Charging Station Location_Houston                                     -0.268132
# Charging Station Location_Los Angeles                                  1.000000
# Charging Station Location_New York                                    -0.263655
# Charging Station Location_San Francisco                               -0.269408
# Time of Day_Evening                                                   -0.018096
# Time of Day_Morning                                                   -0.002499
# Time of Day_Night                                                     -0.000854
# Day of Week_Monday                                                     0.085577
# Day of Week_Saturday                                                  -0.005635
# Day of Week_Sunday                                                    -0.005028
# Day of Week_Thursday                                                   0.001978
# Day of Week_Tuesday                                                    0.015179
# Day of Week_Wednesday                                                 -0.037294
# Charger Type_Level 1                                                   0.010380
# Charger Type_Level 2                                                   0.034915
# User Type_Commuter                                                     0.029848
# User Type_Long-Distance Traveler                                       0.010312
#
#                                           Charging Station Location_New York  \
# Battery Capacity (kWh)                                              0.037707
# Energy Consumed (kWh)                                              -0.008843
# Charging Duration (hours)                                          -0.034760
# Charging Rate (kW)                                                  0.007797
# Charging Cost (USD)                                                -0.002198
# State of Charge (Start %)                                          -0.001565
# State of Charge (End %)                                             0.044312
# Distance Driven (since last charge) (km)                            0.050170
# Temperature (°C)                                                    0.008188
# Vehicle Age (years)                                                 0.032137
# Vehicle Model_Chevy Bolt                                           -0.031326
# Vehicle Model_Hyundai Kona                                          0.012503
# Vehicle Model_Nissan Leaf                                           0.018203
# Vehicle Model_Tesla Model 3                                         0.046512
# Charging Station Location_Houston                                  -0.243502
# Charging Station Location_Los Angeles                              -0.263655
# Charging Station Location_New York                                  1.000000
# Charging Station Location_San Francisco                            -0.244661
# Time of Day_Evening                                                -0.008309
# Time of Day_Morning                                                 0.022426
# Time of Day_Night                                                  -0.078016
# Day of Week_Monday                                                 -0.020666
# Day of Week_Saturday                                               -0.056171
# Day of Week_Sunday                                                 -0.004897
# Day of Week_Thursday                                                0.013449
# Day of Week_Tuesday                                                 0.023354
# Day of Week_Wednesday                                               0.048161
# Charger Type_Level 1                                                0.009386
# Charger Type_Level 2                                               -0.009254
# User Type_Commuter                                                  0.036148
# User Type_Long-Distance Traveler                                   -0.026180
#
#                                           Charging Station Location_San Francisco  \
# Battery Capacity (kWh)                                                   0.033006
# Energy Consumed (kWh)                                                   -0.010470
# Charging Duration (hours)                                                0.061577
# Charging Rate (kW)                                                      -0.002012
# Charging Cost (USD)                                                     -0.025889
# State of Charge (Start %)                                               -0.038068
# State of Charge (End %)                                                  0.020861
# Distance Driven (since last charge) (km)                                 0.035894
# Temperature (°C)                                                         0.042261
# Vehicle Age (years)                                                     -0.021740
# Vehicle Model_Chevy Bolt                                                 0.037363
# Vehicle Model_Hyundai Kona                                              -0.024552
# Vehicle Model_Nissan Leaf                                               -0.014286
# Vehicle Model_Tesla Model 3                                             -0.009266
# Charging Station Location_Houston                                       -0.248816
# Charging Station Location_Los Angeles                                   -0.269408
# Charging Station Location_New York                                      -0.244661
# Charging Station Location_San Francisco                                  1.000000
# Time of Day_Evening                                                      0.019528
# Time of Day_Morning                                                     -0.013913
# Time of Day_Night                                                        0.020506
# Day of Week_Monday                                                      -0.049102
# Day of Week_Saturday                                                     0.010458
# Day of Week_Sunday                                                       0.009691
# Day of Week_Thursday                                                     0.012979
# Day of Week_Tuesday                                                     -0.005282
# Day of Week_Wednesday                                                    0.003189
# Charger Type_Level 1                                                    -0.011135
# Charger Type_Level 2                                                     0.027464
# User Type_Commuter                                                      -0.020510
# User Type_Long-Distance Traveler                                         0.002415
#
#                                           Time of Day_Evening  \
# Battery Capacity (kWh)                               0.032548
# Energy Consumed (kWh)                                0.015618
# Charging Duration (hours)                           -0.009616
# Charging Rate (kW)                                  -0.011762
# Charging Cost (USD)                                 -0.009703
# State of Charge (Start %)                           -0.039932
# State of Charge (End %)                             -0.010488
# Distance Driven (since last charge) (km)            -0.003995
# Temperature (°C)                                     0.014668
# Vehicle Age (years)                                 -0.002877
# Vehicle Model_Chevy Bolt                             0.007705
# Vehicle Model_Hyundai Kona                          -0.020948
# Vehicle Model_Nissan Leaf                           -0.001294
# Vehicle Model_Tesla Model 3                          0.029957
# Charging Station Location_Houston                   -0.016397
# Charging Station Location_Los Angeles               -0.018096
# Charging Station Location_New York                  -0.008309
# Charging Station Location_San Francisco              0.019528
# Time of Day_Evening                                  1.000000
# Time of Day_Morning                                 -0.359206
# Time of Day_Night                                   -0.341994
# Day of Week_Monday                                  -0.018269
# Day of Week_Saturday                                 0.013035
# Day of Week_Sunday                                   0.002991
# Day of Week_Thursday                                 0.046373
# Day of Week_Tuesday                                 -0.004018
# Day of Week_Wednesday                               -0.009654
# Charger Type_Level 1                                 0.018265
# Charger Type_Level 2                                -0.036930
# User Type_Commuter                                   0.012238
# User Type_Long-Distance Traveler                     0.004172
#
#                                           Time of Day_Morning  \
# Battery Capacity (kWh)                               0.016271
# Energy Consumed (kWh)                               -0.017804
# Charging Duration (hours)                           -0.021336
# Charging Rate (kW)                                   0.042012
# Charging Cost (USD)                                 -0.007453
# State of Charge (Start %)                            0.025056
# State of Charge (End %)                             -0.013326
# Distance Driven (since last charge) (km)             0.001630
# Temperature (°C)                                    -0.000069
# Vehicle Age (years)                                  0.000070
# Vehicle Model_Chevy Bolt                            -0.013916
# Vehicle Model_Hyundai Kona                          -0.020417
# Vehicle Model_Nissan Leaf                            0.012324
# Vehicle Model_Tesla Model 3                         -0.005414
# Charging Station Location_Houston                    0.005708
# Charging Station Location_Los Angeles               -0.002499
# Charging Station Location_New York                   0.022426
# Charging Station Location_San Francisco             -0.013913
# Time of Day_Evening                                 -0.359206
# Time of Day_Morning                                  1.000000
# Time of Day_Night                                   -0.325102
# Day of Week_Monday                                  -0.005465
# Day of Week_Saturday                                -0.020080
# Day of Week_Sunday                                   0.001888
# Day of Week_Thursday                                -0.006501
# Day of Week_Tuesday                                  0.010142
# Day of Week_Wednesday                                0.018813
# Charger Type_Level 1                                -0.017661
# Charger Type_Level 2                                 0.012205
# User Type_Commuter                                  -0.000593
# User Type_Long-Distance Traveler                    -0.019352
#
#                                           Time of Day_Night  \
# Battery Capacity (kWh)                            -0.027038
# Energy Consumed (kWh)                             -0.014665
# Charging Duration (hours)                          0.050562
# Charging Rate (kW)                                -0.014142
# Charging Cost (USD)                               -0.012393
# State of Charge (Start %)                          0.003159
# State of Charge (End %)                            0.029840
# Distance Driven (since last charge) (km)          -0.035701
# Temperature (°C)                                  -0.039774
# Vehicle Age (years)                                0.016739
# Vehicle Model_Chevy Bolt                          -0.020336
# Vehicle Model_Hyundai Kona                         0.013902
# Vehicle Model_Nissan Leaf                          0.024864
# Vehicle Model_Tesla Model 3                       -0.022602
# Charging Station Location_Houston                  0.067385
# Charging Station Location_Los Angeles             -0.000854
# Charging Station Location_New York                -0.078016
# Charging Station Location_San Francisco            0.020506
# Time of Day_Evening                               -0.341994
# Time of Day_Morning                               -0.325102
# Time of Day_Night                                  1.000000
# Day of Week_Monday                                 0.027084
# Day of Week_Saturday                               0.012532
# Day of Week_Sunday                                -0.036219
# Day of Week_Thursday                              -0.024440
# Day of Week_Tuesday                               -0.011303
# Day of Week_Wednesday                             -0.022838
# Charger Type_Level 1                               0.028116
# Charger Type_Level 2                               0.000484
# User Type_Commuter                                -0.027886
# User Type_Long-Distance Traveler                   0.017844
#
#                                           Day of Week_Monday  \
# Battery Capacity (kWh)                              0.007902
# ...
# Charging Station Location_San Francisco             0.009691
# Time of Day_Evening                                 0.002991
# Time of Day_Morning                                 0.001888
# Time of Day_Night                                  -0.036219
# Day of Week_Monday                                 -0.166057
# Day of Week_Saturday                               -0.176364
# Day of Week_Sunday                                  1.000000
# Day of Week_Thursday                               -0.149479
# Day of Week_Tuesday                                -0.173810
# Day of Week_Wednesday                              -0.172271
# Charger Type_Level 1                                0.038815
# Charger Type_Level 2                               -0.061372
# User Type_Commuter                                 -0.003928
# User Type_Long-Distance Traveler                   -0.037673
#
#                                           Day of Week_Thursday  \
# Battery Capacity (kWh)                                0.008664
# Energy Consumed (kWh)                                -0.004046
# Charging Duration (hours)                             0.044018
# Charging Rate (kW)                                    0.008088
# Charging Cost (USD)                                   0.059044
# State of Charge (Start %)                             0.022391
# State of Charge (End %)                              -0.048482
# Distance Driven (since last charge) (km)             -0.015175
# Temperature (°C)                                      0.028218
# Vehicle Age (years)                                   0.021798
# Vehicle Model_Chevy Bolt                              0.018702
# Vehicle Model_Hyundai Kona                           -0.006079
# Vehicle Model_Nissan Leaf                            -0.013845
# Vehicle Model_Tesla Model 3                           0.001924
# Charging Station Location_Houston                    -0.038852
# Charging Station Location_Los Angeles                 0.001978
# Charging Station Location_New York                    0.013449
# Charging Station Location_San Francisco               0.012979
# Time of Day_Evening                                   0.046373
# Time of Day_Morning                                  -0.006501
# Time of Day_Night                                    -0.024440
# Day of Week_Monday                                   -0.146723
# Day of Week_Saturday                                 -0.155830
# Day of Week_Sunday                                   -0.149479
# Day of Week_Thursday                                  1.000000
# Day of Week_Tuesday                                  -0.153574
# Day of Week_Wednesday                                -0.152214
# Charger Type_Level 1                                  0.002230
# Charger Type_Level 2                                 -0.031620
# User Type_Commuter                                   -0.022280
# User Type_Long-Distance Traveler                      0.015128
#
#                                           Day of Week_Tuesday  \
# Battery Capacity (kWh)                              -0.014417
# Energy Consumed (kWh)                               -0.017914
# Charging Duration (hours)                            0.039032
# Charging Rate (kW)                                   0.002069
# Charging Cost (USD)                                 -0.043297
# State of Charge (Start %)                            0.022084
# State of Charge (End %)                              0.035103
# Distance Driven (since last charge) (km)             0.005879
# Temperature (°C)                                    -0.015744
# Vehicle Age (years)                                  0.035053
# Vehicle Model_Chevy Bolt                             0.049229
# Vehicle Model_Hyundai Kona                           0.003671
# Vehicle Model_Nissan Leaf                           -0.002093
# Vehicle Model_Tesla Model 3                         -0.059045
# Charging Station Location_Houston                   -0.003692
# Charging Station Location_Los Angeles                0.015179
# Charging Station Location_New York                   0.023354
# Charging Station Location_San Francisco             -0.005282
# Time of Day_Evening                                 -0.004018
# Time of Day_Morning                                  0.010142
# Time of Day_Night                                   -0.011303
# Day of Week_Monday                                  -0.170606
# Day of Week_Saturday                                -0.181195
# Day of Week_Sunday                                  -0.173810
# Day of Week_Thursday                                -0.153574
# Day of Week_Tuesday                                  1.000000
# Day of Week_Wednesday                               -0.176990
# Charger Type_Level 1                                -0.006856
# Charger Type_Level 2                                -0.005871
# User Type_Commuter                                  -0.013734
# User Type_Long-Distance Traveler                     0.021497
#
#                                           Day of Week_Wednesday  \
# Battery Capacity (kWh)                                 0.020267
# Energy Consumed (kWh)                                  0.033907
# Charging Duration (hours)                              0.002616
# Charging Rate (kW)                                    -0.037480
# Charging Cost (USD)                                    0.027409
# State of Charge (Start %)                              0.007871
# State of Charge (End %)                               -0.034995
# Distance Driven (since last charge) (km)              -0.035778
# Temperature (°C)                                      -0.040913
# Vehicle Age (years)                                    0.016224
# Vehicle Model_Chevy Bolt                               0.041910
# Vehicle Model_Hyundai Kona                             0.022799
# Vehicle Model_Nissan Leaf                             -0.004293
# Vehicle Model_Tesla Model 3                           -0.030101
# Charging Station Location_Houston                     -0.032523
# Charging Station Location_Los Angeles                 -0.037294
# Charging Station Location_New York                     0.048161
# Charging Station Location_San Francisco                0.003189
# Time of Day_Evening                                   -0.009654
# Time of Day_Morning                                    0.018813
# Time of Day_Night                                     -0.022838
# Day of Week_Monday                                    -0.169095
# Day of Week_Saturday                                  -0.179590
# Day of Week_Sunday                                    -0.172271
# Day of Week_Thursday                                  -0.152214
# Day of Week_Tuesday                                   -0.176990
# Day of Week_Wednesday                                  1.000000
# Charger Type_Level 1                                  -0.002242
# Charger Type_Level 2                                   0.034804
# User Type_Commuter                                     0.021964
# User Type_Long-Distance Traveler                      -0.000989
#
#                                           Charger Type_Level 1  \
# Battery Capacity (kWh)                                0.012108
# Energy Consumed (kWh)                                -0.032940
# Charging Duration (hours)                            -0.018244
# Charging Rate (kW)                                    0.001886
# Charging Cost (USD)                                  -0.060721
# State of Charge (Start %)                             0.031706
# State of Charge (End %)                               0.006631
# Distance Driven (since last charge) (km)              0.007185
# Temperature (°C)                                      0.005470
# Vehicle Age (years)                                  -0.000441
# Vehicle Model_Chevy Bolt                             -0.000073
# Vehicle Model_Hyundai Kona                            0.025794
# Vehicle Model_Nissan Leaf                            -0.025634
# Vehicle Model_Tesla Model 3                           0.029714
# Charging Station Location_Houston                    -0.008393
# Charging Station Location_Los Angeles                 0.010380
# Charging Station Location_New York                    0.009386
# Charging Station Location_San Francisco              -0.011135
# Time of Day_Evening                                   0.018265
# Time of Day_Morning                                  -0.017661
# Time of Day_Night                                     0.028116
# Day of Week_Monday                                    0.025984
# Day of Week_Saturday                                 -0.036383
# Day of Week_Sunday                                    0.038815
# Day of Week_Thursday                                  0.002230
# Day of Week_Tuesday                                  -0.006856
# Day of Week_Wednesday                                -0.002242
# Charger Type_Level 1                                  1.000000
# Charger Type_Level 2                                 -0.508385
# User Type_Commuter                                   -0.018280
# User Type_Long-Distance Traveler                      0.020427
#
#                                           Charger Type_Level 2  \
# Battery Capacity (kWh)                               -0.001796
# Energy Consumed (kWh)                                 0.074079
# Charging Duration (hours)                             0.009248
# Charging Rate (kW)                                    0.017854
# Charging Cost (USD)                                  -0.006427
# State of Charge (Start %)                            -0.017769
# State of Charge (End %)                              -0.022819
# Distance Driven (since last charge) (km)             -0.043631
# Temperature (°C)                                      0.006684
# Vehicle Age (years)                                  -0.016743
# Vehicle Model_Chevy Bolt                              0.013942
# Vehicle Model_Hyundai Kona                           -0.051764
# Vehicle Model_Nissan Leaf                             0.000431
# Vehicle Model_Tesla Model 3                          -0.021435
# Charging Station Location_Houston                    -0.042719
# Charging Station Location_Los Angeles                 0.034915
# Charging Station Location_New York                   -0.009254
# Charging Station Location_San Francisco               0.027464
# Time of Day_Evening                                  -0.036930
# Time of Day_Morning                                   0.012205
# Time of Day_Night                                     0.000484
# Day of Week_Monday                                    0.007421
# Day of Week_Saturday                                  0.035970
# Day of Week_Sunday                                   -0.061372
# Day of Week_Thursday                                 -0.031620
# Day of Week_Tuesday                                  -0.005871
# Day of Week_Wednesday                                 0.034804
# Charger Type_Level 1                                 -0.508385
# Charger Type_Level 2                                  1.000000
# User Type_Commuter                                    0.062507
# User Type_Long-Distance Traveler                     -0.046987
#
#                                           User Type_Commuter  \
# Battery Capacity (kWh)                              0.009218
# Energy Consumed (kWh)                              -0.042261
# Charging Duration (hours)                           0.025339
# Charging Rate (kW)                                  0.050738
# Charging Cost (USD)                                 0.014027
# State of Charge (Start %)                           0.020893
# State of Charge (End %)                             0.034269
# Distance Driven (since last charge) (km)            0.047292
# Temperature (°C)                                    0.023104
# Vehicle Age (years)                                 0.007581
# Vehicle Model_Chevy Bolt                            0.050617
# Vehicle Model_Hyundai Kona                         -0.019356
# Vehicle Model_Nissan Leaf                          -0.014906
# Vehicle Model_Tesla Model 3                         0.000117
# Charging Station Location_Houston                  -0.037494
# Charging Station Location_Los Angeles               0.029848
# Charging Station Location_New York                  0.036148
# Charging Station Location_San Francisco            -0.020510
# Time of Day_Evening                                 0.012238
# Time of Day_Morning                                -0.000593
# Time of Day_Night                                  -0.027886
# Day of Week_Monday                                  0.037667
# Day of Week_Saturday                                0.013398
# Day of Week_Sunday                                 -0.003928
# Day of Week_Thursday                               -0.022280
# Day of Week_Tuesday                                -0.013734
# Day of Week_Wednesday                               0.021964
# Charger Type_Level 1                               -0.018280
# Charger Type_Level 2                                0.062507
# User Type_Commuter                                  1.000000
# User Type_Long-Distance Traveler                   -0.528315
#
#                                           User Type_Long-Distance Traveler
# Battery Capacity (kWh)                                           -0.014165
# Energy Consumed (kWh)                                            -0.009695
# Charging Duration (hours)                                        -0.035206
# Charging Rate (kW)                                               -0.037230
# Charging Cost (USD)                                              -0.022044
# State of Charge (Start %)                                         0.024344
# State of Charge (End %)                                          -0.060313
# Distance Driven (since last charge) (km)                          0.008700
# Temperature (°C)                                                 -0.046820
# Vehicle Age (years)                                              -0.000493
# Vehicle Model_Chevy Bolt                                          0.001012
# Vehicle Model_Hyundai Kona                                        0.007777
# Vehicle Model_Nissan Leaf                                         0.015884
# Vehicle Model_Tesla Model 3                                      -0.022434
# Charging Station Location_Houston                                 0.037383
# Charging Station Location_Los Angeles                             0.010312
# Charging Station Location_New York                               -0.026180
# Charging Station Location_San Francisco                           0.002415
# Time of Day_Evening                                               0.004172
# Time of Day_Morning                                              -0.019352
# Time of Day_Night                                                 0.017844
# Day of Week_Monday                                               -0.056790
# Day of Week_Saturday                                              0.040591
# Day of Week_Sunday                                               -0.037673
# Day of Week_Thursday                                              0.015128
# Day of Week_Tuesday                                               0.021497
# Day of Week_Wednesday                                            -0.000989
# Charger Type_Level 1                                              0.020427
# Charger Type_Level 2                                             -0.046987
# User Type_Commuter                                               -0.528315
# User Type_Long-Distance Traveler                                  1.000000

# %%
''' Checking for correaltions, for this dataset very weak correlation exists between values. The correlation is in order
    of 0.08, which is the highest. '''

filtered_corr = corr_mat[(corr_mat > 0.08) & (corr_mat != 1)]
filter_stack = filtered_corr.stack()
filter_stack
# Out:
# Charging Duration (hours)              Vehicle Model_Chevy Bolt                 0.084768
# State of Charge (End %)                Day of Week_Saturday                     0.084987
# Vehicle Model_Chevy Bolt               Charging Duration (hours)                0.084768
# Charging Station Location_Los Angeles  Day of Week_Monday                       0.085577
# Day of Week_Monday                     Charging Station Location_Los Angeles    0.085577
# Day of Week_Saturday                   State of Charge (End %)                  0.084987
# dtype: float64

# %%
''' Pairplot helps us to have a visual look at what relationship exists between the attributes of our data.'''

sns.pairplot(df)

# %%
''' Taking a look at the distribution of Users. '''

def pie_chart(df):

  plt.figure(dpi = 144)

  explode = [0.025, 0.025, 0.025]
  labels = pd.unique(df['User Type'])

  plt.pie(df['User Type'].value_counts(), explode = explode, autopct = '%1.1f%%', labels = labels)
  plt.title('Driver Distribution')

  plt.show()

  return

# %%
pie_chart(df)

# %% [markdown]
# The data is almost equally distributed as among the drivers, so there is no bias in the data on this basis.

# %%
''' Checking skewness and kurtosis of charging duration to get better idea of data distribution '''
print(df['Charging Duration (hours)'].skew())
print(df['Charging Duration (hours)'].kurt())
# Out:
# 0.3613086527002225
# 0.23963332629822132

# %% [markdown]
# As both kurtosis and skewness are postive and close to 0, it shows that data distribution is close to normal with only slight deviation.

# %%
''' Making a stacked bar chart to study the charging time required for different car models on average and how it
    varies according to the charger type. '''

def stacked_bar(df):

  df_pivot = df.pivot_table(index = 'Vehicle Model', columns = 'Charger Type', values = 'Charging Duration (hours)',
                            aggfunc = 'sum')

  plt.figure(dpi = 144)

  df_pivot.plot(kind = 'bar', stacked = True, figsize = (10, 7))

  plt.ylabel('Charging Time (hours)')
  plt.xlabel('Car Model')
  plt.title('Charging Duration relation by car model and charger type')
  plt.xticks(rotation=45)

  plt.legend(title='Charger type', loc = 'best', fontsize = 8)

  plt.grid(True, linewidth = 0.35)

  plt.show()

  return

# %%
stacked_bar(df)

# %%
''' Checking skewness and kurtosis of charging rate to get better idea of data distribution '''
print(df['Charging Rate (kW)'].skew())
print(df['Charging Rate (kW)'].kurt())
print(df['Temperature (°C)'].kurt())
# Out:
# 0.2550185987359237
# -0.3325833227414483
# -0.8666522534392902

# %% [markdown]
# Chraging rate has few extreme outliers and slight variance but majorly follows normal distribution.

# %%
''' Creating a scatter plot between Charging rate and Temperature to study their relationship.  '''

def scatter_plot (df):

  plt.figure(dpi = 144)

  sns.jointplot(x = df['Charging Rate (kW)'], y = df['Temperature (°C)'], marginal_ticks=True, color = 'Green')

  plt.ylabel('Temperature (°C)')
  plt.xlabel('Charging Rate (kW)')
  plt.title('Temperature variation as per Charging rate', y = 1.25, loc = 'center')


  plt.show()

# %%
scatter_plot(df)

# %%
''' Making a boxplot to study the pattern between Charging duration and Day of the week.'''

def boxplot(df):

  plt.figure(dpi = 144)

  sns.boxplot(data = df, x = 'Day of Week', y = 'Charging Duration (hours)', fill = False,
              order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])

  plt.xticks(rotation = 45)

  plt.grid(True)

  plt.title('Charging time across the week')

  plt.show()

# %%
boxplot(df)
